# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf as pdf
import numpy as np
import pandas as pd
import colors as EL

# %%
def plot_trajectory(animal, color, savename):
    filename = "./data/trajectories/video_calculations/"+animal+'.csv'
    temp = pd.read_csv(filename)
    
    fig = plt.figure(figsize = (8, 3))
    ax = fig.add_subplot(111, aspect="equal")
    
    alpha = 1
    ax.plot(temp['pos_x_mm'], temp['pos_y_mm'], color=color, lw=2, alpha=alpha, zorder=0)
    
    # Set boundaries of the figure
    ax.set_xlim(0, 80)
    ax.set_ylim(30, 0)
    
    # Remove padding and margins from the figure and all its subplots
    plt.margins(0,0)
    plt.subplots_adjust(top=1, bottom=0, right=1, left=0, hspace=0, wspace=0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())

    # Save the Matplotlib figure as a PDF file:
    pp = pdf.PdfPages(savename, keep_empty=False)
    pp.savefig(fig)
    pp.close()
    
    # Show the figure
    plt.show()

# %%
plot_trajectory('190808-04-A-top', EL.culex_q, './figures/quinque_plot.pdf')
plot_trajectory('190712-03-A-top', EL.arabiensis, './figures/arabiensis_plot.pdf')
plot_trajectory('190626-04-A-top', EL.aegypti, './figures/aegypti_plot.pdf')
plot_trajectory('190725-06-A-top', EL.coluzzii, './figures/coluzzii_plot.pdf')
plot_trajectory('190628-04-A-bottom', EL.albopictus, './figures/albopictus_plot.pdf')
plot_trajectory('191126-02-A-top', EL.culex_t, './figures/tarsalis_plot.pdf')

# %%
# 4 CULEX TARSALIS (for presentations)

plot_trajectory('191126-02-A-top', EL.culex_t, './figures/tarsalis_plot1.pdf')
plot_trajectory('191126-06-A-top', EL.culex_t, './figures/tarsalis_plot2.pdf')
plot_trajectory('191126-09-A-bottom', EL.culex_t, './figures/tarsalis_plot3.pdf')
plot_trajectory('191127-03-A-top', EL.culex_t, './figures/tarsalis_plot4.pdf')

# %%
# 4 AEDES AEGYPTI (for presentations)

plot_trajectory('190626-04-A-top', EL.aegypti, './figures/aegypti_plot1.pdf')
plot_trajectory('190626-02-A-bottom', EL.aegypti, './figures/aegypti_plot2.pdf')
plot_trajectory('190626-03-A-top', EL.aegypti, './figures/aegypti_plot3.pdf')
plot_trajectory('190626-03-A-bottom', EL.aegypti, './figures/aegypti_plot4.pdf')

# %%
# 4 AEDES ALBOPICTUS (for presentations)

plot_trajectory('190628-04-A-bottom', EL.albopictus, './figures/albopictus_plot1.pdf')
plot_trajectory('190628-01-A-top', EL.albopictus, './figures/albopictus_plot2.pdf')
plot_trajectory('190628-02-A-bottom', EL.albopictus, './figures/albopictus_plot3.pdf')
plot_trajectory('190628-03-A-top', EL.albopictus, './figures/albopictus_plot4.pdf')

# %%
# 4 ANOPHELES ARABIENSIS (for presentations)

plot_trajectory('190712-03-A-top', EL.arabiensis, './figures/arabiensis_plot1.pdf')

plot_trajectory('190712-06-A-bottom', EL.arabiensis, './figures/arabiensis_plot2.pdf')
plot_trajectory('190712-01-A-bottom', EL.arabiensis, './figures/arabiensis_plot3.pdf')
plot_trajectory('190712-03-A-bottom', EL.arabiensis, './figures/arabiensis_plot4.pdf')

# %%
# 4 ANOPHELES COLUZZII (for presentations)

plot_trajectory('190725-06-A-top', EL.coluzzii, './figures/coluzzii_plot1.pdf')
plot_trajectory('190724-03-A-top', EL.coluzzii, './figures/coluzzii_plot2.pdf')
plot_trajectory('190724-01-A-bottom', EL.coluzzii, './figures/coluzzii_plot3.pdf')
plot_trajectory('190724-04-A-top', EL.coluzzii, './figures/coluzzii_plot4.pdf')

# %%
# 4 CULEX QUINQUEFASCIATUS (for presentations)

plot_trajectory('190808-04-A-top', EL.culex_q, './figures/quinque_plot1.pdf')
plot_trajectory('190805-01-A-top', EL.culex_q, './figures/quinque_plot2.pdf')
plot_trajectory('190820-06-A-bottom', EL.culex_q, './figures/quinque_plot3.pdf')
plot_trajectory('190805-05-A-top', EL.culex_q, './figures/quinque_plot4.pdf')
